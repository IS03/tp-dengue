# %%
import sys
sys.path.append("../ETL")  # o la ruta absoluta
from clima.transform_por_estacion import *
import pandas as pd

# %%
path = '../data/datos-estaciones/A872840.xls'
df_crudo = pd.read_excel(path)
df_crudo.head()
# Out:
#                    Fecha  Temperatura_Abrigo_150cm  \
# 0  2014-11-12 00:00:00.0                       NaN
# 1  2014-11-13 00:00:00.0                  20.07361
# 2  2014-11-14 00:00:00.0                  21.56181
# 3  2014-11-15 00:00:00.0                  20.39375
# 4  2014-11-16 00:00:00.0                  21.34722
#
#    Temperatura_Abrigo_150cm_Maxima  Temperatura_Abrigo_150cm_Minima  \
# 0                              NaN                              NaN
# 1                             30.3                              9.5
# 2                             31.3                             10.9
# 3                             32.0                              8.3
# 4                             31.9                              9.7
#
#    Temperatura_Intemperie_5cm_Minima  Temperatura_Intemperie_50cm_Minima  \
# 0                                NaN                                 NaN
# 1                                NaN                                 NaN
# ...

# %%
df_crudo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3886 entries, 0 to 3885
# Data columns (total 30 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Fecha                                3886 non-null   object
#  1   Temperatura_Abrigo_150cm             3672 non-null   float64
#  2   Temperatura_Abrigo_150cm_Maxima      3660 non-null   float64
#  3   Temperatura_Abrigo_150cm_Minima      3660 non-null   float64
#  4   Temperatura_Intemperie_5cm_Minima    0 non-null      float64
#  5   Temperatura_Intemperie_50cm_Minima   0 non-null      float64
#  6   Temperatura_Suelo_5cm_Media          0 non-null      float64
#  7   Temperatura_Suelo_10cm_Media         3671 non-null   float64
#  8   Temperatura_Inte_5cm                 0 non-null      float64
#  9   Temperatura_Intemperie_150cm_Minima  0 non-null      float64
#  10  Humedad_Suelo                        0 non-null      float64
# ...

# %%
pipeline(df_crudo, path)
# Out:
# INFO - id_estacion inferido desde archivo: A872840
# WARNING - Radiación: regresión no pudo entrenarse/aplicarse (Found array with 0 sample(s) (shape=(0, 1)) while a minimum of 1 is required by LinearRegression.). Se continúa con interpolación.
# INFO - Eliminadas 3886 filas con nulos en ['radiacion_global'].
# Empty DataFrame
# Columns: [fecha, id_estacion, precipitacion_pluviometrica, temperatura_minima, temperatura_maxima, temperatura_media, humedad_media, rocio_medio, tesion_vapor_media, radiacion_global, heliofania_efectiva, heliofania_relativa]
# Index: []

# %%
df_limpio
# Out:
# Empty DataFrame
# Columns: [fecha, precipitacion_pluviometrica, temperatura_minima, temperatura_maxima, temperatura_media, humedad_media, rocio_medio, tesion_vapor_media, radiacion_global, heliofania_efectiva, heliofania_relativa]
# Index: []
