# %%
import pandas as pd
import os

# %% [markdown]
# Para poder seleccionar bien las variables a utilizar, creo un dataframe mucho mas chico para no tener que procesar la totalidad de los datos.

# %%
df = pd.read_parquet('../data/datos-todas-estaciones.parquet')
df.columns = [col.lower().strip() for col in df.columns]

df_mini = df.copy()[:1000]

# %% [markdown]
# ### Selección de variables.

# %%
df.sample(10)
# Out:
#                         fecha id_estacion  temperatura_abrigo_150cm_minima  \
# 897294  1986-07-24 00:00:00.0      NH0502                              3.2
# 314100  2022-11-07 00:00:00.0     A872924                              8.2
# 270436  2019-02-08 00:00:00.0     A872909                             20.9
# 266145  2019-06-15 00:00:00.0     A872908                             21.1
# 59313   2014-04-10 00:00:00.0     A872819                              8.5
# 194575  2015-12-10 00:00:00.0     A872867                             15.6
# 180332  2013-11-09 00:00:00.0     A872862                             17.9
# 40358   2023-04-29 00:00:00.0     A872812                             17.2
# 792168  2022-09-16 00:00:00.0      NH0460                              9.0
# 219749  2015-06-28 00:00:00.0     A872885                              2.8
#
#         temperatura_abrigo_150cm_maxima  temperatura_abrigo_150cm  \
# 897294                             21.4                 12.300000
# 314100                             23.4                 16.202780
# 270436                             38.2                 29.183340
# 266145                             29.4                 24.189580
# 59313                              19.8                 13.552780
# 194575                             32.0                 23.615280
# 180332                             24.8                 19.788890
# 40358                              33.1                 23.867360
# 792168                             25.0                 17.000000
# 219749                             19.3                  9.321527
#
#         precipitacion_pluviometrica  humedad_media_8_14_20  \
# 897294                      0.00000                   75.0
# 314100                      0.00000                   37.0
# 270436                      0.00000                   66.0
# 266145                      0.00000                   70.0
# 59313                       0.00000                   74.0
# 194575                      0.00000                   64.0
# 180332                     46.99998                   89.0
# 40358                       0.00000                   71.0
# 792168                      0.00000                   60.0
# 219749                      0.00000                   76.0
#
#         tesion_vapor_media  rocio_medio  horas_frio
# 897294           10.400000     7.500000    5.010989
# 314100            7.799369     3.387188    0.000000
# 270436           20.926620          NaN    0.000000
# 266145           21.489460    18.641640    0.000000
# 59313            11.635050     9.123349    0.000000
# 194575           19.927240    17.347800    0.000000
# 180332           21.221980    18.441050    0.000000
# 40358            24.393930    20.552640    0.000000
# 792168           13.348049    11.060313         NaN
# 219749            8.595918     4.758533   10.458000

# %%
features = (df.isna().sum() * 100 / len(df)).reset_index()
features.columns = ['columna', 'percentNa']

features.sort_values('percentNa').query('percentNa <= 99')
# Out:
#                                 columna  percentNa
# 0                                 fecha   0.000000
# 30                          id_estacion   0.000000
# 3       temperatura_abrigo_150cm_minima   6.066566
# 2       temperatura_abrigo_150cm_maxima   6.360656
# 1              temperatura_abrigo_150cm   6.553649
# 11          precipitacion_pluviometrica   7.020599
# 18                humedad_media_8_14_20   9.662863
# 16                   tesion_vapor_media  10.929604
# 19                          rocio_medio  12.666109
# 28                           horas_frio  14.436710
# 21         velocidad_viento_200cm_media  37.908162
# 23        velocidad_viento_1000cm_media  37.966504
# 27                     radiacion_global  45.444745
# 14                  heliofania_efectiva  45.491396
# 15                  heliofania_relativa  46.319330
# 24              direccion_viento_1000cm  48.130954
# 22               direccion_viento_200cm  54.232265
# 35         evapotranspiracion_potencial  56.006330
# 17                        humedad_media  58.389790
# 7          temperatura_suelo_10cm_media  58.534724
# 12            precipitacion_cronologica  61.084117
# 29                        unidades_frio  61.160427
# 13       precipitacion_maxima_30minutos  61.506905
# 4     temperatura_intemperie_5cm_minima  64.515022
# 31                              granizo  66.185934
# 32                                nieve  67.276459
# 25              velocidad_viento_maxima  83.998238
# 20              duracion_follaje_mojado  90.060582
# 26                        presion_media  90.787743
# 5    temperatura_intemperie_50cm_minima  91.217134
# 9   temperatura_intemperie_150cm_minima  95.275294
# 33                       radiacion_neta  95.426073
# 6           temperatura_suelo_5cm_media  96.302065
# 36                     profundidad_napa  97.709411

# %%
cols = features.sort_values('percentNa').query('percentNa <= 15').columna.values
cols
# Out:
# array(['fecha', 'id_estacion', 'temperatura_abrigo_150cm_minima',
#        'temperatura_abrigo_150cm_maxima', 'temperatura_abrigo_150cm',
#        'precipitacion_pluviometrica', 'humedad_media_8_14_20',
#        'tesion_vapor_media', 'rocio_medio', 'horas_frio'], dtype=object)

# %%
unidades = {'fecha': 'fecha',
 'temperatura_abrigo_150cm': '°C',
 'temperatura_abrigo_150cm_maxima': '°C',
 'temperatura_abrigo_150cm_minima': '°C',
 'temperatura_intemperie_5cm_minima': '°C',
 'temperatura_intemperie_50cm_minima': '°C',
 'temperatura_suelo_5cm_media': '°C',
 'temperatura_suelo_10cm_media': '°C',
 'temperatura_inte_5cm': '°C',
 'temperatura_intemperie_150cm_minima': '°C',
 'humedad_suelo': '%',
 'precipitacion_pluviometrica': 'mm',
 'precipitacion_cronologica': 'mm',
 'precipitacion_maxima_30minutos': 'mm',
 'heliofania_efectiva': 'horas',
 'heliofania_relativa': '%',
 'tesion_vapor_media': 'hPa',
 'humedad_media': '%',
 'humedad_media_8_14_20': '%',
 'rocio_medio': '°C',
 'duracion_follaje_mojado': 'horas',
 'velocidad_viento_200cm_media': 'm/s',
 'direccion_viento_200cm': 'grados',
 'velocidad_viento_1000cm_media': 'm/s',
 'direccion_viento_1000cm': 'grados',
 'velocidad_viento_maxima': 'm/s',
 'presion_media': 'hPa',
 'radiacion_global': 'MJ/m²',
 'horas_frio': 'horas',
 'unidades_frio': 'unidades'}

unidades_completas = {
    "fecha": "Fecha (día, mes, año, hora)",
    "°C": "Grados Celsius (temperatura)",
    "%": "Porcentaje (%)",
    "mm": "Milímetros (precipitación)",
    "horas": "Horas",
    "hPa": "Hectopascales (presión o tensión de vapor)",
    "m/s": "Metros por segundo (velocidad del viento)",
    "grados": "Grados (dirección del viento, 0° a 360°)",
    "MJ/m²": "Megajulios por metro cuadrado (radiación solar)",
    "unidades": "Unidades de frío (índice agroclimático)"
}

# %% [markdown]
# ## Valores nulos.

# %%
pd.set_option("display.max_columns", 200)

# %%
df = df[cols]
df.isna().sum()
# Out:
# fecha                                   0
# id_estacion                             0
# temperatura_abrigo_150cm_minima     56047
# temperatura_abrigo_150cm_maxima     58764
# temperatura_abrigo_150cm            60547
# precipitacion_pluviometrica         64861
# humedad_media_8_14_20               89272
# tesion_vapor_media                 100975
# rocio_medio                        117018
# horas_frio                         133376
# dtype: int64

# %%
df.isna().sum()
# Out:
# fecha                                   0
# id_estacion                             0
# temperatura_abrigo_150cm_minima     56047
# temperatura_abrigo_150cm_maxima     58764
# temperatura_abrigo_150cm            60547
# precipitacion_pluviometrica         64861
# humedad_media_8_14_20               89272
# tesion_vapor_media                 100975
# rocio_medio                        117018
# horas_frio                         133376
# dtype: int64

# %% [markdown]
# Detectar las filas en donde la temperatura minima o maxima sean nulos pero la "temperatura_abrigo_150cm" tenga algun valor, para poder incrustar ese valor en la minima y la maxima.

# %%
df.loc[
    ((df.temperatura_abrigo_150cm_minima.isna()) | (df.temperatura_abrigo_150cm_maxima.isna()))& (~df.temperatura_abrigo_150cm.isna())
]
# Out:
#                         fecha id_estacion  temperatura_abrigo_150cm_minima  \
# 31      2009-09-06 00:00:00.0     A872801                              NaN
# 46      2009-09-21 00:00:00.0     A872801                              NaN
# 56      2009-10-05 00:00:00.0     A872801                              NaN
# 157     2010-08-27 00:00:00.0     A872801                              NaN
# 515     2012-03-16 00:00:00.0     A872801                              NaN
# ...                       ...         ...                              ...
# 863604  1995-04-30 00:00:00.0      NH0496                              NaN
# 919081  2012-08-03 00:00:00.0      NH0550                              NaN
# 919689  2014-04-03 00:00:00.0      NH0550                              NaN
# 919710  2014-04-24 00:00:00.0      NH0550                              NaN
# 919723  2014-05-07 00:00:00.0      NH0550                              NaN
#
#         temperatura_abrigo_150cm_maxima  temperatura_abrigo_150cm  \
# 31                                  NaN                  17.01880
# 46                                  NaN                  17.26667
# 56                                  NaN                  21.57314
# 157                                 NaN                  14.47664
# 515                                 NaN                  17.99207
# ...                                 ...                       ...
# 863604                              NaN                  13.15000
# 919081                              NaN                   8.40000
# 919689                              NaN                  25.80000
# 919710                              NaN                  20.75000
# 919723                              NaN                  21.40000
#
#         precipitacion_pluviometrica  humedad_media_8_14_20  \
# 31                              NaN                   71.0
# 46                              NaN                   51.0
# 56                              NaN                   79.0
# 157                             NaN                   83.0
# 515                             NaN                    NaN
# ...                             ...                    ...
# 863604                          2.5                    NaN
# 919081                          0.0                   65.0
# 919689                          6.0                   89.0
# 919710                          0.0                   77.0
# 919723                          0.0                   95.0
#
#         tesion_vapor_media  rocio_medio  horas_frio
# 31                14.43417    12.425080         0.0
# 46                11.16542     8.536985         0.0
# 56                18.58017    16.252500         0.0
# 157               14.33899    12.238580         0.0
# 515               16.23893    14.219770         0.0
# ...                    ...          ...         ...
# 863604                 NaN          NaN         0.0
# 919081             7.20000     2.200000         0.0
# 919689            29.50000    23.800000         0.0
# 919710            18.80000    16.600000         0.0
# 919723            24.20000    20.600000         0.0
#
# [2075 rows x 10 columns]

# %% [markdown]
# Cambio los valores nulos de la fila de horas_frio por 0.0

# %%
df.horas_frio = df.horas_frio.fillna(0.0)

# %% [markdown]
# Para los datos de **temperatura_abrigo_150cm_maxima** y **temperatura_abrigo_150cm_maxima** que tiene  valores nulos pero la columna **temperatura_abrigo_150cm** tiene algun valor, se me ocrrio de hacer lo siguiente:
#
# Detectar en el mes de ese registro cuanto difieren los valores de minima y maxima con el de **temperatura_abrigo_150cm**. Despues sacar un promedio y el resultado asignarselo a los valores nulos.

# %% [markdown]
# Si hay una semana con valores nulos en la temperatura, imputar los valores de la misma  pero de un año anterior.

# %%
(df.temperatura_abrigo_150cm_minima - df.temperatura_abrigo_150cm).mean()
# Out:
# np.float64(-6.47521352250143)

# %%
df[
    (df.temperatura_abrigo_150cm_minima.isna()) & (df.temperatura_abrigo_150cm_minima.shift(1).notna())
]
# Out:
#                         fecha id_estacion  temperatura_abrigo_150cm_minima  \
# 20      2009-08-26 00:00:00.0     A872801                              NaN
# 30      2009-09-05 00:00:00.0     A872801                              NaN
# 43      2009-09-18 00:00:00.0     A872801                              NaN
# 46      2009-09-21 00:00:00.0     A872801                              NaN
# 56      2009-10-05 00:00:00.0     A872801                              NaN
# ...                       ...         ...                              ...
# 923792  2025-06-29 00:00:00.0      NH0550                              NaN
# 923802  2025-07-09 00:00:00.0      NH0550                              NaN
# 923818  2025-07-25 00:00:00.0      NH0550                              NaN
# 923826  2025-08-02 00:00:00.0      NH0550                              NaN
# 923855  2025-08-31 00:00:00.0      NH0550                              NaN
#
#         temperatura_abrigo_150cm_maxima  temperatura_abrigo_150cm  \
# 20                                  NaN                       NaN
# 30                                  NaN                       NaN
# 43                                  NaN                       NaN
# 46                                  NaN                  17.26667
# 56                                  NaN                  21.57314
# ...                                 ...                       ...
# 923792                              NaN                       NaN
# 923802                              NaN                       NaN
# 923818                             16.5                       NaN
# 923826                             20.5                       NaN
# 923855                             20.3                       NaN
#
#         precipitacion_pluviometrica  humedad_media_8_14_20  \
# 20                              NaN                    NaN
# 30                              NaN                    NaN
# 43                              NaN                    NaN
# 46                              NaN                   51.0
# 56                              NaN                   79.0
# ...                             ...                    ...
# 923792                          0.0                    NaN
# 923802                          0.0                    NaN
# 923818                          3.0                   88.0
# 923826                          0.0                    NaN
# 923855                          0.0                    NaN
#
#         tesion_vapor_media  rocio_medio  horas_frio
# 20                     NaN          NaN         0.0
# 30                     NaN          NaN         0.0
# 43                     NaN          NaN         0.0
# 46               11.165420     8.536985         0.0
# 56               18.580170    16.252500         0.0
# ...                    ...          ...         ...
# 923792                 NaN          NaN         0.0
# 923802                 NaN          NaN         0.0
# 923818           14.304822    12.277325         0.0
# 923826                 NaN          NaN         0.0
# 923855                 NaN          NaN         0.0
#
# [5940 rows x 10 columns]

# %%
df[
    (df.temperatura_abrigo_150cm_minima.notna()) & (df.temperatura_abrigo_150cm_minima.shift(-1).isna())
]
# Out:
#                         fecha id_estacion  temperatura_abrigo_150cm_minima  \
# 19      2009-08-25 00:00:00.0     A872801                             12.1
# 29      2009-09-04 00:00:00.0     A872801                              9.7
# 42      2009-09-17 00:00:00.0     A872801                             10.8
# 45      2009-09-20 00:00:00.0     A872801                              3.7
# 55      2009-10-04 00:00:00.0     A872801                             13.4
# ...                       ...         ...                              ...
# 923801  2025-07-08 00:00:00.0      NH0550                             10.4
# 923817  2025-07-24 00:00:00.0      NH0550                              8.5
# 923825  2025-08-01 00:00:00.0      NH0550                             12.5
# 923854  2025-08-30 00:00:00.0      NH0550                             15.0
# 923866  2025-09-11 00:00:00.0      NH0550                             12.7
#
#         temperatura_abrigo_150cm_maxima  temperatura_abrigo_150cm  \
# 19                                 27.6                  18.62847
# 29                                 16.8                  12.92362
# 42                                 14.9                  12.77292
# 45                                 22.4                  12.98750
# 55                                 23.7                  18.44653
# ...                                 ...                       ...
# 923801                             28.4                  19.40000
# 923817                             11.2                   9.85000
# 923825                             28.4                  20.45000
# 923854                             30.5                  22.75000
# 923866                             29.4                  21.05000
#
#         precipitacion_pluviometrica  humedad_media_8_14_20  \
# 19                              0.0                   65.0
# 29                              NaN                   93.0
# 42                              NaN                   90.0
# 45                              0.0                   59.0
# 55                             29.6                   66.0
# ...                             ...                    ...
# 923801                          0.0                    NaN
# 923817                          0.0                    NaN
# 923825                          0.0                   76.0
# 923854                          1.5                    NaN
# 923866                          0.0                    NaN
#
#         tesion_vapor_media  rocio_medio  horas_frio
# 19               15.120320    13.128280    0.000000
# 29               13.497310    11.394110    0.000000
# 42               13.144750    10.889290    0.000000
# 45                9.660729     6.431308    6.473997
# 55               15.116120    13.101610    0.000000
# ...                    ...          ...         ...
# 923801                 NaN          NaN    0.000000
# 923817                 NaN          NaN    0.000000
# 923825           17.947170    15.665318    0.000000
# 923854                 NaN          NaN    0.000000
# 923866                 NaN          NaN    0.000000
#
# [5941 rows x 10 columns]
